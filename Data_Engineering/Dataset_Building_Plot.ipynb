# %%
import numpy as np
import open3d as o3d
import os
import matplotlib.pyplot as plt
import gc
import pandas as pd

# %%
# %matplotlib notebook

# %%
DYNAMIC_FOLDER2 = "/home/saby/Projects/ati/data/data/datasets/Carla/64beam-Data/dynamic/"
DYNAMIC_FOLDER = "/home/saby/Projects/ati/data/data/datasets/Carla/64beam-Data/testing/dynamic/"
STATIC_FOLDER = "/home/saby/Projects/ati/data/data/datasets/Carla/64beam-Data/static/"
GT_FILE = "groundTruth.csv"

# %% [raw]
# plt.figure()
# for sub_folder in sorted(os.listdir(DYNAMIC_FOLDER)):
# #     print(sub_folder)
# #     plt.figure()
#     gt_path = os.path.join(DYNAMIC_FOLDER, sub_folder, GT_FILE)
#     df_gt = pd.read_csv(gt_path)
#     plt.plot(df_gt['location_x'], df_gt['location_y'], label=sub_folder)
# plt.legend()

# %%
plt.figure()
for sub_folder in sorted(os.listdir(DYNAMIC_FOLDER)):
#     print(sub_folder)
#     plt.figure()
    axes = plt.gca()
    axes.set_xlim([-10,410])
    axes.set_ylim([-10,350])
    gt_path = os.path.join(DYNAMIC_FOLDER, sub_folder, GT_FILE)
    df_gt = pd.read_csv(gt_path)
    plt.plot(df_gt['location_x'], df_gt['location_y'], 'k--', linewidth=0.5)
# plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [raw]
# # plt.figure()
# dynamic_selected_set= {5,8,9,13}
# for sub_folder in sorted(os.listdir(DYNAMIC_FOLDER2)):
# #     print(sub_folder)
#     sub_folder_int = int(sub_folder)
#     if sub_folder_int not in dynamic_selected_set:
#         continue
#     plt.figure()
#     axes = plt.gca()
#     axes.set_xlim([-10,410])
#     axes.set_ylim([-10,350])
#     gt_path = os.path.join(DYNAMIC_FOLDER2, sub_folder, GT_FILE)
#     df_gt = pd.read_csv(gt_path)
#     plt.plot(df_gt['location_x'], df_gt['location_y'], label=sub_folder)
#     plt.legend()

# %% [raw]
# # plt.figure()
# static_selected_set = {1,2,3,5}
# for sub_folder in sorted(os.listdir(STATIC_FOLDER)):
# #     print(sub_folder)
#     sub_folder_int = int(sub_folder)
#     if sub_folder_int not in static_selected_set:
#         continue
#     plt.figure()
#     axes = plt.gca()
#     axes.set_xlim([-10,410])
#     axes.set_ylim([-10,350])
#     gt_path = os.path.join(STATIC_FOLDER, sub_folder, GT_FILE)
#     df_gt = pd.read_csv(gt_path)
#     plt.plot(df_gt['location_x'], df_gt['location_y'], label=sub_folder)
#     plt.legend()

# %% [raw]
# for dynamic_sub_folder in sorted(os.listdir(DYNAMIC_FOLDER2)):
#     for static_sub_folder in sorted(os.listdir(STATIC_FOLDER)):
#         static_sub_folder_int = int(static_sub_folder)
#         if static_sub_folder_int not in static_selected_set:
#             continue
#         dynamic_sub_folder_int = int(dynamic_sub_folder)
#         if dynamic_sub_folder_int not in dynamic_selected_set:
#             continue
#         print(dynamic_sub_folder, static_sub_folder)
#         plt.figure()
#         axes = plt.gca()
#         axes.set_xlim([-10,410])
#         axes.set_ylim([-10,350])
#
#         static_gt_path = os.path.join(STATIC_FOLDER, static_sub_folder, GT_FILE)
#         static_df_gt = pd.read_csv(static_gt_path)
#         plt.plot(static_df_gt['location_x'], static_df_gt['location_y'], 'c', label=static_sub_folder)
#
#         dynamic_gt_path = os.path.join(DYNAMIC_FOLDER2, dynamic_sub_folder, GT_FILE)
#         dynamic_df_gt = pd.read_csv(dynamic_gt_path)
#         plt.plot(dynamic_df_gt['location_x'], dynamic_df_gt['location_y'], 'm', label=dynamic_sub_folder)
#         plt.legend()

# %%
dynamic_df_gt.shape, static_df_gt.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-71b9558bf685> in <module>
# ----> 1 dynamic_df_gt.shape, static_df_gt.shape
#
# NameError: name 'dynamic_df_gt' is not defined

# %%
size = dynamic_df_gt.shape[0]
np.arange(1,size,int(size/4))[1:-1]
# Out:
# array([ 564, 1127, 1690])

# %%
plt.figure(figsize=(10,10))
# for sub_folder in sorted(os.listdir(DYNAMIC_FOLDER)):
# #     print(sub_folder)
# #     plt.figure()
#     axes = plt.gca()
#     axes.set_xlim([-10,410])
#     axes.set_ylim([-10,350])
#     gt_path = os.path.join(DYNAMIC_FOLDER, sub_folder, GT_FILE)
#     df_gt = pd.read_csv(gt_path)
#     if sub_folder == "17":
#         plt.plot(df_gt['location_x'], df_gt['location_y'], 'k--', linewidth=0.5, label="carla_roads")
#     else:
#         plt.plot(df_gt['location_x'], df_gt['location_y'], 'k--', linewidth=0.5)

size=20
dynamic_color = "r"
dynamic_gt_path = os.path.join(DYNAMIC_FOLDER2, "5", GT_FILE)
dynamic_df_gt = pd.read_csv(dynamic_gt_path)
plt.plot(dynamic_df_gt['location_x'], dynamic_df_gt['location_y'], dynamic_color, label="dynamic run")

static_color = "k"
static_gt_path = os.path.join(STATIC_FOLDER, "5", GT_FILE)
static_df_gt = pd.read_csv(static_gt_path)
plt.plot(static_df_gt['location_x'], static_df_gt['location_y'], static_color, label="static run")

plt.legend(loc='center', fontsize=size*1.75)

# Blue arrows
plt.scatter([dynamic_df_gt.iloc[0]['location_x'], dynamic_df_gt.iloc[-1]['location_x']],
            [dynamic_df_gt.iloc[0]['location_y'], dynamic_df_gt.iloc[-1]['location_y']],
            c=dynamic_color, s=30)
# plt.annotate("Dynamic_Start", (dynamic_df_gt.iloc[0]['location_x']+3, dynamic_df_gt.iloc[0]['location_y']-3), c=dynamic_color, fontsize=size)
# plt.annotate("Dynamic_End", (dynamic_df_gt.iloc[-1]['location_x']+3, dynamic_df_gt.iloc[-1]['location_y']-3), c=dynamic_color, fontsize=size)
plt.arrow(dynamic_df_gt.iloc[100]['location_x'],
          dynamic_df_gt.iloc[100]['location_y'],
          0, 0.1,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=dynamic_color)
plt.arrow(dynamic_df_gt.iloc[520]['location_x'],
          dynamic_df_gt.iloc[520]['location_y'],
          0.1, 0,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=dynamic_color)
plt.arrow(dynamic_df_gt.iloc[720]['location_x'],
          dynamic_df_gt.iloc[720]['location_y'],
          0.1, 0,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=dynamic_color)
plt.arrow(dynamic_df_gt.iloc[1260]['location_x'],
          dynamic_df_gt.iloc[1260]['location_y'],
          0, -0.1,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=dynamic_color)
plt.arrow(dynamic_df_gt.iloc[1300]['location_x'],
          dynamic_df_gt.iloc[1300]['location_y'],
          -0.1, 0,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=dynamic_color)
plt.arrow(dynamic_df_gt.iloc[1760]['location_x'],
          dynamic_df_gt.iloc[1760]['location_y'],
          -0.1, 0,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=dynamic_color)
plt.arrow(dynamic_df_gt.iloc[2150]['location_x'],
          dynamic_df_gt.iloc[2150]['location_y'],
          0, -0.1,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=dynamic_color)

#Yellow arrows
plt.scatter([static_df_gt.iloc[0]['location_x'], static_df_gt.iloc[-1]['location_x']],
            [static_df_gt.iloc[0]['location_y'], static_df_gt.iloc[-1]['location_y']],
            c=static_color, s=30)
# plt.annotate("Static_Start", (static_df_gt.iloc[0]['location_x']-5, static_df_gt.iloc[0]['location_y']-12), c=static_color, fontsize=size)
# plt.annotate("Static_End", (static_df_gt.iloc[-1]['location_x']-55, static_df_gt.iloc[-1]['location_y']-3), c=static_color, fontsize=size)
plt.arrow(static_df_gt.iloc[100]['location_x'],
          static_df_gt.iloc[100]['location_y'],
          -0.1, 0,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=static_color)
plt.arrow(static_df_gt.iloc[780]['location_x'],
          static_df_gt.iloc[780]['location_y'],
          0, 0.1,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=static_color)
plt.arrow(static_df_gt.iloc[850]['location_x'],
          static_df_gt.iloc[850]['location_y'],
          0.1, 0,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=static_color)
plt.arrow(static_df_gt.iloc[1050]['location_x'],
          static_df_gt.iloc[1050]['location_y'],
          0.1, 0,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=static_color)
plt.arrow(static_df_gt.iloc[1200]['location_x'],
          static_df_gt.iloc[1200]['location_y'],
          0, 0.1,
          shape='full', lw=0, length_includes_head=True, head_width=5, color=static_color)

plt.axis('off')
plt.savefig("1st.png")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# plt.figure()
# for sub_folder in sorted(os.listdir(DYNAMIC_FOLDER)):
# #     print(sub_folder)
# #     plt.figure()
#     axes = plt.gca()
#     axes.set_xlim([-10,410])
#     axes.set_ylim([-10,350])
#     gt_path = os.path.join(DYNAMIC_FOLDER, sub_folder, GT_FILE)
#     df_gt = pd.read_csv(gt_path)
#     if sub_folder == "17":
#         plt.plot(df_gt['location_x'], df_gt['location_y'], 'k--', linewidth=0.5, label="carla_roads")
#     else:
#         plt.plot(df_gt['location_x'], df_gt['location_y'], 'k--', linewidth=0.5)

fig, ax = plt.subplots(figsize=(10,10))

dynamic_gt_path = os.path.join(DYNAMIC_FOLDER2, "5", GT_FILE)
dynamic_df_gt = pd.read_csv(dynamic_gt_path)
plt.scatter(dynamic_df_gt['location_x'], dynamic_df_gt['location_y'], c='r', s=5)#, 'ro', label="dynamic_run")
# plt.plot(dynamic_df_gt['location_x'], dynamic_df_gt['location_y'], 'ro', label="dynamic_run")

static_gt_path = os.path.join(STATIC_FOLDER, "5", GT_FILE)
static_df_gt = pd.read_csv(static_gt_path)
plt.scatter(static_df_gt['location_x'], static_df_gt['location_y'], c='k', s=5)#, 'ks', label="static run")
# plt.plot(static_df_gt['location_x'], static_df_gt['location_y'], 'ks', label="static run")

# plt.legend()

for idx, row in dynamic_df_gt.iterrows():
    circle = plt.Circle((row['location_x'],row['location_y']), 0.5, color=(1,0,0,0.1))
    ax.add_artist(circle)
#     plt.annotate(str(int(row['step'])), (row['location_x'], row['location_y']), c=dynamic_color)
    
# for idx, row in static_df_gt.iterrows():
#     circle = plt.Circle((row['location_x'],row['location_y']), 0.5, color=(0,0,0,0.1))
#     ax.add_artist(circle)
#     plt.annotate(str(int(row['step'])), (row['location_x'], row['location_y']), c=static_color)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# At turn:
# dynamic - 1152 (6130 -> 2033 idx)
# static - 1113
#
# dynamic - 1145 (6123 -> 2026)
# static - 1104

# %%
6130/2048

# %%
2048*2 + 2034

# %%
6123-4096
