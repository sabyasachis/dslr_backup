# %% [markdown]
# Imports

# %%
import pdb
import numpy as np
import os, shutil
from tqdm import tqdm_notebook
import pandas as pd
import open3d as o3d
import gc
import zipfile
from multiprocessing import Pool, cpu_count
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:80% !important; }</style>"))

# %% [markdown]
# Set Paths and constants

# %%
# pcd_folder='/home/sabyasachi/Projects/ati/data/data/datasets/Carla/lidarParam1/pair_corrupt/dynamic/'
# npy_folder='/home/sabyasachi/Projects/ati/data/data/datasets/Carla/lidarParam1/pair_corrupt/dynamic_NPY/'

BASE_PATH = '/home/sabyasachi/Projects/ati/data/data/datasets/Carla/few_dynamic_runs/110k/'
STATIC_FOLDER = "static"
# Do for both
PCD_FOLDER = "_out"
# PCD_FOLDER = "dynamic"
EXTRACTED_ARRAY_FNAME = "arr_0.npy"

# BATCH_SIZE = 80000
BATCH_SIZE = 2048
RANGE_IMAGE_HEIGHT = 32
RANGE_IMAGE_WIDTH = 512

# %% [markdown]
# Preprocessing functions from the paper source code

# %%
def get_quadrant(point):
    if point[0] >= 0. and point[1] >= 0. :
        return 0
    elif point[0] <= 0. and point[1] >= 0. : 
        return 1
    elif point[0] <= 0. and point[1] <= 0. : 
        return 2
    elif point[0] >= 0. and point[1] <= 0. : 
        return 3
    else :
        raise Exception('invalid input %s', point) 


def passed_origin(x_t, x_t1):
    if get_quadrant(x_t1) == 3 and get_quadrant(x_t) == 0: 
        return True
    else : 
        return False


def fit_quadrant(points, quadrant, desired_amt):
    
    
    points = np.asarray(points)
    slots = []
    slot_size = np.pi / (2 * desired_amt)
    for i in range(int(desired_amt)) : slots.append([])
    if quadrant == 0: 
        points = points[::-1]
    elif quadrant == 1 : 
        points[:, 0] = - points[:, 0]
    elif quadrant == 2 :
        points = points[::-1] 
        points[:, 0] = - points[:, 0]
        points[:, 1] = - points[:, 1]
    elif quadrant == 3 : 
        points[:, 1] = - points[:, 1]

    # import pdb; pdb.set_trace()
    for point in points :
        angle = np.arctan(point[1] / (point[0]+0.000001))
        index = min(int(angle / slot_size), desired_amt - 1)
        slots[int(index)].append(point)

    for i in range(len(slots)):
        if len(slots[i]) == 0 : 
            slots[i] = np.array([0., 0., 0., 0.])
        else :
            full_slot = np.asarray(slots[i])
            slots[i] = full_slot.mean(axis=0)

    points = np.asarray(slots)
    if quadrant == 0: 
        points = points[::-1]
    elif quadrant == 1 : 
        points[:, 0] = - points[:, 0]
    elif quadrant == 2 : 
        points = points[::-1]
        points[:, 0] = - points[:, 0]
        points[:, 1] = - points[:, 1]
    elif quadrant == 3 : 
        points[:, 1] = - points[:, 1]

    return points

def parse_velo(velo):
    # points closer to the origin (0,0,0) are at the end of the point cloud.
    # invert the point cloud such that we begin near the origin. 
    
    # returns: a H x 4 x ? array, split into quadrants
    velo = velo[::-1]
    lines = []
    current_point = velo[0]
    current_quadrant = get_quadrant(current_point)
    current_line = [[], [], [], []]
    quadrant_switches = 0
    for point in velo :
        point_quadrant = get_quadrant(point)
        
        if passed_origin(current_point, point):
            lines.append(current_line)
            current_line = [[], [], [], []]

        current_line[point_quadrant].append(point)
        current_quadrant = point_quadrant
        current_point = point

    return lines


def setmatch(lines,lenLines):
    arr=[[np.array([0,0,0,0]),np.array([0,0,0,0])]]
    if len(lines) > lenLines:
        return lines[:lenLines]
    else:
        for i in range(abs(len(lines)-lenLines)):
            lines.append(arr)
    return lines

def process_velo(velo, points_per_layer, stop=False):
    
    lenLines=RANGE_IMAGE_HEIGHT
    lines = parse_velo(velo)
    inverse = quad_to_pc_inv(lines)
    lines = lines[2:-1]
#     print(lines[])
#     print((lines[0]))
#     raise SystemError
    if(len(lines)!=lenLines):
        lines=setmatch(lines,lenLines)
#     print(len(lines), flush=True)
    if len(lines) != RANGE_IMAGE_HEIGHT : raise Exception('invalid nb un of lines')
    out_tensor = np.zeros((RANGE_IMAGE_HEIGHT, points_per_layer, 4))
    if stop:
        import pdb; pdb.set_trace()
        x = 1
    for j in range(len(lines)):
        line = lines[j]
        out_line = np.zeros((points_per_layer, 4))
        for i in range(len(line)):
            if(len(line[i])==0):
                line[i]=[np.array([0.0,0.0,0.0,0.0])]
            gridded = fit_quadrant(line[i], i, points_per_layer / 4)
            out_tensor[j][i*int(points_per_layer/4):(i+1)*int(points_per_layer/4), :] = gridded[::-1]

    return out_tensor, inverse


def quad_to_pc_inv(lines, th=3.):
    # lines is a 63 x 4 array, where each slot has an array of 4d/3d points
    # goal : get an array of points that fills empty spaces
    points = []
    for i in range(len(lines)) :
        line = lines[i] 
        distance = []
        for quad in line : 
            for point in quad : 
                x, y, z = point[:3]
                distance.append(x**2 + y**2)
        distance = np.array(distance)
        std = distance.std()
        sorted_indices = np.argsort(distance)
        median_index = sorted_indices[int(sorted_indices.shape[0]*0.95)]
        median = distance[median_index]

        for quad in line : 
            for point in quad : 
                x, y, z = point[:3]
                dist = x ** 2 + y ** 2 
                if dist < median and (median/dist-1.) > th:#*std : 
                    # blocked point --> scale to get real pt
                    scale = np.sqrt(median / dist)
                    scaled = scale * point
                    points.append(scaled)


    return np.array(points)

# %%
def getint(name):
    return int(name.split('.')[0])

# %%
def parallel_pcd2begin_npy(pcd_fname):
    pcd_file_path = os.path.join(PCD_PATH, pcd_fname)
    pcd = o3d.read_point_cloud(pcd_file_path)
    pcd_arr = np.asarray(pcd.points)
    pcd_arr = np.append(pcd_arr, np.zeros((pcd_arr.shape[0],1)), axis=1)
    
    npy_fname = pcd_fname[:-4] + ".npy"
    npy_file_path = os.path.join(INITIAL_NPY_PATH, npy_fname)
    pcd_arr.dump(open(npy_file_path, 'wb'))

def parallel_npy2processed(npy_file):
    gc.collect()
    npy_file_path = os.path.join(INITIAL_NPY_PATH, npy_file)
    raw_lidar = np.load(npy_file_path, allow_pickle=True)
    processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
    return processed_lidar

# %% [markdown]
# PCD to NPY files

# %%
for sub_folder in os.listdir(os.path.join(BASE_PATH, STATIC_FOLDER)):
    print("Sub folder: {}".format(sub_folder))
    PCD_PATH = os.path.join(BASE_PATH, STATIC_FOLDER, sub_folder, PCD_FOLDER)
    if not os.path.exists(PCD_PATH):
        print("Did not find : {}".format(PCD_PATH))

    INITIAL_NPY_FOLDER = PCD_FOLDER + "_begin_npy"
    INITIAL_NPY_PATH = os.path.join(BASE_PATH, STATIC_FOLDER, sub_folder, INITIAL_NPY_FOLDER)
    if not os.path.exists(INITIAL_NPY_PATH):
        os.makedirs(INITIAL_NPY_PATH)
    else:
        shutil.rmtree(INITIAL_NPY_PATH)
        os.makedirs(INITIAL_NPY_PATH)

    NPZ_FOLDER = PCD_FOLDER + "_npz"
    NPZ_PATH = os.path.join(BASE_PATH, STATIC_FOLDER, sub_folder, NPZ_FOLDER)
    if not os.path.exists(NPZ_PATH):
        os.makedirs(NPZ_PATH)
    else:
        shutil.rmtree(NPZ_PATH)
        os.makedirs(NPZ_PATH)

    OUT_NPY_FOLDER = PCD_FOLDER + "_out_npy"
    OUT_NPY_PATH = os.path.join(BASE_PATH, STATIC_FOLDER, sub_folder, OUT_NPY_FOLDER)
    if not os.path.exists(OUT_NPY_PATH):
        os.makedirs(OUT_NPY_PATH)
    else:
        shutil.rmtree(OUT_NPY_PATH)
        os.makedirs(OUT_NPY_PATH)



    parallel_npy_args = sorted(os.listdir(PCD_PATH), key=getint)
    process_npy_pool = Pool(cpu_count()-1)
    __ = [each for each in tqdm_notebook(process_npy_pool.imap(parallel_pcd2begin_npy,
                                                           parallel_npy_args),
                                         total = len(parallel_npy_args))]
    process_npy_pool.terminate()
    gc.collect()


    npy_folder_size = len(os.listdir(INITIAL_NPY_PATH))
    leftout_size = npy_folder_size % BATCH_SIZE
    n_batches = int(npy_folder_size / BATCH_SIZE)
    file_list = sorted(os.listdir(INITIAL_NPY_PATH), key=getint)
    full_npy_file_list = np.split(np.array(file_list)[:-leftout_size], n_batches)
    # To consider last small batch
    full_npy_file_list += [np.array(file_list[-leftout_size:])]

    print("No of npzs: {}".format(len(full_npy_file_list)))

    npz_file_idx = 0
    for some_npy_file_list in full_npy_file_list:
        print(len(some_npy_file_list))
        parallel_processed_args = some_npy_file_list
        process_processed_pool = Pool(cpu_count()-1)
        one_run_npy_file = [each for each in tqdm_notebook(process_processed_pool.imap(parallel_npy2processed,
                                                               parallel_processed_args), total=len(parallel_processed_args))]
        process_processed_pool.terminate()
        gc.collect()

        npz_file_path = os.path.join(NPZ_PATH, str(npz_file_idx))
        np.savez(npz_file_path, one_run_npy_file)
        npz_file_idx += 1

    print("Extracting out_npys")
    for npz_fname in tqdm_notebook(sorted(os.listdir(NPZ_PATH), key=getint)):
        npz_path = os.path.join(NPZ_PATH, npz_fname)
        with zipfile.ZipFile(npz_path, 'r') as zip_ref:
            zip_ref.extractall(OUT_NPY_PATH)

        out_npy_fname = npz_fname[:-4] + ".npy"
        src_fname = os.path.join(OUT_NPY_PATH, EXTRACTED_ARRAY_FNAME)
        dst_fname = os.path.join(OUT_NPY_PATH, out_npy_fname)
        os.rename(src_fname, dst_fname)
        
    shutil.rmtree(INITIAL_NPY_PATH)
    shutil.rmtree(NPZ_PATH)
# Out:
# Sub folder: 8
# HBox(children=(IntProgress(value=0, max=493), HTML(value='')))
# No of npzs: 2
# 0
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# 493
# HBox(children=(IntProgress(value=0, max=493), HTML(value='')))
# Extracting out_npys
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# Sub folder: 4
# HBox(children=(IntProgress(value=0, max=2152), HTML(value='')))
# No of npzs: 2
# 0
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# 2152
# HBox(children=(IntProgress(value=0, max=2152), HTML(value='')))
# Process ForkPoolWorker-134:
# Process ForkPoolWorker-133:
# Process ForkPoolWorker-132:
# Process ForkPoolWorker-130:
# Process ForkPoolWorker-129:
# Process ForkPoolWorker-121:
# Process ForkPoolWorker-117:
# Process ForkPoolWorker-124:
# Process ForkPoolWorker-123:
# Process ForkPoolWorker-125:
# Process ForkPoolWorker-131:
# Process ForkPoolWorker-126:
# Process ForkPoolWorker-127:
# Process ForkPoolWorker-128:
# Process ForkPoolWorker-122:
# Process ForkPoolWorker-119:
# Process ForkPoolWorker-120:
# Process ForkPoolWorker-118:
# Process ForkPoolWorker-135:
# Process ForkPoolWorker-136:
# Process ForkPoolWorker-116:
# Process ForkPoolWorker-137:
# Process ForkPoolWorker-138:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-9f2377eb3767>", line 12, in parallel_npy2processed
#     gc.collect()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
# KeyboardInterrupt
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-3-9e6f445e9bc5>", line 103, in process_velo
#     lines = parse_velo(velo)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 103, in process_velo
#     lines = parse_velo(velo)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 103, in process_velo
#     lines = parse_velo(velo)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-9e6f445e9bc5>", line 80, in parse_velo
#     if passed_origin(current_point, point):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 42, in fit_quadrant
#     index = min(int(angle / slot_size), desired_amt - 1)
#   File "<ipython-input-3-9e6f445e9bc5>", line 80, in parse_velo
#     if passed_origin(current_point, point):
#   File "<ipython-input-3-9e6f445e9bc5>", line 42, in fit_quadrant
#     index = min(int(angle / slot_size), desired_amt - 1)
#   File "<ipython-input-3-9e6f445e9bc5>", line 78, in parse_velo
#     point_quadrant = get_quadrant(point)
#   File "<ipython-input-3-9e6f445e9bc5>", line 41, in fit_quadrant
#     angle = np.arctan(point[1] / (point[0]+0.000001))
#   File "<ipython-input-3-9e6f445e9bc5>", line 15, in passed_origin
#     if get_quadrant(x_t1) == 3 and get_quadrant(x_t) == 0:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-3-9e6f445e9bc5>", line 104, in process_velo
#     inverse = quad_to_pc_inv(lines)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "<ipython-input-3-9e6f445e9bc5>", line 50, in fit_quadrant
#     slots[i] = full_slot.mean(axis=0)
#   File "<ipython-input-3-9e6f445e9bc5>", line 15, in passed_origin
#     if get_quadrant(x_t1) == 3 and get_quadrant(x_t) == 0:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-3-9e6f445e9bc5>", line 8, in get_quadrant
#     elif point[0] >= 0. and point[1] <= 0. :
# KeyboardInterrupt
#   File "<ipython-input-3-9e6f445e9bc5>", line 103, in process_velo
#     lines = parse_velo(velo)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-9e6f445e9bc5>", line 138, in quad_to_pc_inv
#     x, y, z = point[:3]
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-3-9e6f445e9bc5>", line 6, in get_quadrant
#     elif point[0] <= 0. and point[1] <= 0. :
#   File "<ipython-input-3-9e6f445e9bc5>", line 80, in parse_velo
#     if passed_origin(current_point, point):
# KeyboardInterrupt
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
# KeyboardInterrupt
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 50, in fit_quadrant
#     slots[i] = full_slot.mean(axis=0)
#   File "<ipython-input-3-9e6f445e9bc5>", line 15, in passed_origin
#     if get_quadrant(x_t1) == 3 and get_quadrant(x_t) == 0:
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-3-9e6f445e9bc5>", line 50, in fit_quadrant
#     slots[i] = full_slot.mean(axis=0)
#   File "<ipython-input-3-9e6f445e9bc5>", line 2, in get_quadrant
#     if point[0] >= 0. and point[1] >= 0. :
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
# KeyboardInterrupt
#   File "<ipython-input-3-9e6f445e9bc5>", line 50, in fit_quadrant
#     slots[i] = full_slot.mean(axis=0)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/_methods.py", line 75, in _mean
#     ret = umr_sum(arr, axis, dtype, out, keepdims)
#   File "<ipython-input-3-9e6f445e9bc5>", line 50, in fit_quadrant
#     slots[i] = full_slot.mean(axis=0)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/_methods.py", line 62, in _mean
#     rcount = _count_reduce_items(arr, axis)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/_methods.py", line 76, in _mean
#     if isinstance(ret, mu.ndarray):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/_methods.py", line 51, in _count_reduce_items
#     if not isinstance(axis, tuple):
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/_methods.py", line 69, in _mean
#     if issubclass(arr.dtype.type, (nt.integer, nt.bool_)):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
# KeyboardInterrupt
#   File "<ipython-input-3-9e6f445e9bc5>", line 50, in fit_quadrant
#     slots[i] = full_slot.mean(axis=0)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/_methods.py", line 78, in _mean
#     ret, rcount, out=ret, casting='unsafe', subok=False)
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-5-9f2377eb3767>", line 15, in parallel_npy2processed
#     processed_lidar, _ = process_velo(raw_lidar, RANGE_IMAGE_WIDTH)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 123, in process_velo
#     gridded = fit_quadrant(line[i], i, points_per_layer / 4)
#   File "<ipython-input-3-9e6f445e9bc5>", line 49, in fit_quadrant
#     full_slot = np.asarray(slots[i])
#   File "<ipython-input-3-9e6f445e9bc5>", line 49, in fit_quadrant
#     full_slot = np.asarray(slots[i])
#   File "<ipython-input-3-9e6f445e9bc5>", line 49, in fit_quadrant
#     full_slot = np.asarray(slots[i])
#   File "<ipython-input-3-9e6f445e9bc5>", line 49, in fit_quadrant
#     full_slot = np.asarray(slots[i])
#   File "<ipython-input-3-9e6f445e9bc5>", line 52, in fit_quadrant
#     points = np.asarray(slots)
#   File "<ipython-input-3-9e6f445e9bc5>", line 49, in fit_quadrant
#     full_slot = np.asarray(slots[i])
#   File "<ipython-input-3-9e6f445e9bc5>", line 50, in fit_quadrant
#     slots[i] = full_slot.mean(axis=0)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/numeric.py", line 538, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/numeric.py", line 538, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/numeric.py", line 538, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/numeric.py", line 538, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/numeric.py", line 538, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/_methods.py", line 59, in _mean
#     arr = asanyarray(a)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/numeric.py", line 538, in asarray
#     return array(a, dtype, copy=False, order=order)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/site-packages/numpy/core/numeric.py", line 591, in asanyarray
#     return array(a, dtype, copy=False, order=order, subok=True)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     732             try:
# --> 733                 item = self._items.popleft()
#     734             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d973ebf80511> in <module>
#      57         process_processed_pool = Pool(cpu_count()-1)
#      58         one_run_npy_file = [each for each in tqdm_notebook(process_processed_pool.imap(parallel_npy2processed,
# ---> 59                                                                parallel_processed_args), total=len(parallel_processed_args))]
#      60         process_processed_pool.terminate()
#      61         gc.collect()
#
# <ipython-input-6-d973ebf80511> in <listcomp>(.0)
#      56         parallel_processed_args = some_npy_file_list
#      57         process_processed_pool = Pool(cpu_count()-1)
# ---> 58         one_run_npy_file = [each for each in tqdm_notebook(process_processed_pool.imap(parallel_npy2processed,
#      59                                                                parallel_processed_args), total=len(parallel_processed_args))]
#      60         process_processed_pool.terminate()
#
# ~/anaconda3/envs/deepmapping/lib/python3.7/site-packages/tqdm/_tqdm_notebook.py in __iter__(self, *args, **kwargs)
#     221     def __iter__(self, *args, **kwargs):
#     222         try:
# --> 223             for obj in super(tqdm_notebook, self).__iter__(*args, **kwargs):
#     224                 # return super(tqdm...) will not catch exception
#     225                 yield obj
#
# ~/anaconda3/envs/deepmapping/lib/python3.7/site-packages/tqdm/_tqdm.py in __iter__(self)
#    1003                 """), fp_write=getattr(self.fp, 'write', sys.stderr.write))
#    1004
# -> 1005             for obj in iterable:
#    1006                 yield obj
#    1007                 # Update and possibly print the progressbar.
#
# ~/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     735                 if self._index == self._length:
#     736                     raise StopIteration from None
# --> 737                 self._cond.wait(timeout)
#     738                 try:
#     739                     item = self._items.popleft()
#
# ~/anaconda3/envs/deepmapping/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
full_npy_file_list
# Out:
# [array([], dtype='<U8'),
#  array(['1.npy', '2.npy', '3.npy', ..., '2150.npy', '2151.npy', '2152.npy'],
#        dtype='<U8')]
