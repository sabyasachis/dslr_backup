# %%
import pandas as pd
import numpy as np
import gc
from tqdm.notebook import tqdm_notebook 
import os, shutil
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
BASE_PATH = "/home/saby/Projects/ati/data/data/datasets/iisc/2020-02-10"

STATIC_DATA_FOLDER = "2020-02-10-15-32-49-p15-auto-5loops_static"
DYNAMIC_1_DATA_FOLDER = "2020-02-10-15-57-38-p15-auto-5loops_dy_1"
DYNAMIC_2_DATA_FOLDER = "2020-02-10-16-12-42-p15-auto-5loops_dy_2"

STATIC_DATA_PATH = os.path.join(BASE_PATH, STATIC_DATA_FOLDER, "debug")
DYNAMIC_1_DATA_PATH = os.path.join(BASE_PATH, DYNAMIC_1_DATA_FOLDER, "debug")
DYNAMIC_2_DATA_PATH = os.path.join(BASE_PATH, DYNAMIC_2_DATA_FOLDER, "debug")

YELLI_FILE = "yelli_odo.csv"
YELLI_STATIC_PATH = os.path.join(STATIC_DATA_PATH, YELLI_FILE)
YELLI_DYNAMIC_1_PATH = os.path.join(DYNAMIC_1_DATA_PATH, YELLI_FILE)
YELLI_DYNAMIC_2_PATH = os.path.join(DYNAMIC_2_DATA_PATH, YELLI_FILE)

# %%
df_static = pd.read_csv(YELLI_STATIC_PATH)
df_dynamic_1 = pd.read_csv(YELLI_DYNAMIC_1_PATH)
df_dynamic_2 = pd.read_csv(YELLI_DYNAMIC_2_PATH)
df_static.shape, df_dynamic_1.shape, df_dynamic_2.shape
# Out:
# ((6344, 6), (7496, 6), (7191, 6))

# %%
df_static.head()
# Out:
#    frame_id          time         x         y    z     theta
# 0        52  1.581329e+09  0.099527 -0.317001  0.0  1.700805
# 1        53  1.581329e+09  0.109442 -0.315704  0.0  1.700860
# 2        54  1.581329e+09  0.107590 -0.301539  0.0  1.700858
# 3        55  1.581329e+09  0.107590 -0.301539  0.0  1.700882
# 4        56  1.581329e+09  0.107590 -0.301539  0.0  1.700845

# %%
df_dynamic_1.head()
# Out:
#    frame_id          time         x         y    z     theta
# 0        52  1.581330e+09  0.112280 -0.186463  0.0  1.730805
# 1        53  1.581330e+09  0.110004 -0.172359  0.0  1.730800
# 2        54  1.581330e+09  0.100132 -0.173952  0.0  1.730784
# 3        55  1.581330e+09  0.110004 -0.172359  0.0  1.730837
# 4        56  1.581330e+09  0.119876 -0.170765  0.0  1.730872

# %%
df_dynamic_2.head()
# Out:
#    frame_id          time         x         y    z     theta
# 0        55  1.581331e+09  0.097271 -0.140797  0.0  1.700818
# 1        56  1.581331e+09  0.097271 -0.140797  0.0  1.700847
# 2        57  1.581331e+09  0.097271 -0.140797  0.0  1.700856
# 3        58  1.581331e+09  0.107187 -0.139500  0.0  1.700869
# 4        59  1.581331e+09  0.087355 -0.142093  0.0  1.700834

# %%
plt.figure()
plt.grid()
plt.plot(df_static['x'], df_static['y'], c='r', label='static')
plt.plot(df_dynamic_1['x'], df_dynamic_1['y'], c='g', label='dynamic1')
plt.plot(df_dynamic_2['x'], df_dynamic_2['y'], c='b', label='dynamic2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
