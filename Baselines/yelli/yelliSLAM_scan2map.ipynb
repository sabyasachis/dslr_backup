# %% [markdown]
# It is a Grid Search based SLAM implementation using LIDAR data using the following:
#  - basic : we rotate the destination (later) pcd to destination's (local) grid points to score against source (former) pcd
#  - adaptive grid : grid is interpolated based on velocity instead of distance ; this assumes that there are no sudden acceleration or impulsive forces or jerks
#  - 2d map : creates a 2d map of the environment instead of 3d
#  - parallel : the grid search for every pose has been parallelized on CPU cores

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import gc
from tqdm import *
import os
import copy
import sys
import time
from collections import Counter, deque
from multiprocessing import Pool, cpu_count

import transforms3d

from sklearn.manifold import TSNE, LocallyLinearEmbedding
from sklearn.cluster import MeanShift

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# import ipyvolume as ipv
import open3d as o3d

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# ### Set paths and file names

# %% [raw]
# INVERT_Z = False
# X_GRID = np.arange(-0.2, 0.25, 0.05)
# Y_GRID = np.arange(-0.2, 0.25, 0.05)
# THETA_GRID = np.arange(-2, 2.5, 0.5)
#
# # LIDAR_PCD_PATH = "/home/sabyasachi/Projects/ati/data/data/datasets/IISC/2019-06-12/10-00-14-P1-6-auto-ccw_5loops_0.6_no_numba/complete_extracted"
# LIDAR_PCD_PATH = "/home/sabyasachi/Projects/ati/data/data/datasets/IISC/2019-02-26/ref_run_ccw_r/complete_extracted"
#
#
#
# MAP_FILE = 'map_2019-02-26_ref_run_ccw_r.pcd'
# POSE_FILE = 'pose_2019-02-26_ref_run_ccw_r.json'

# %%
INVERT_Z = True
X_GRID = np.arange(-12, 13, 1)
Y_GRID = np.arange(-12, 13, 1)
THETA_GRID = np.arange(-20, 21, 1)


FIRST_PCD = 2
FINAL_PCD = 1200
LIDAR_PCD_PATH = "/home/sabyasachi/Projects/ati/data/data/datasets/Carla/currentDataforCVPR/template3/static/1/_out"
MAP_FILE = 'map_template3_1.pcd'
POSE_FILE = 'pose_template3_1.json'

# FIRST_PCD = 2
# FINAL_PCD = 5512
# LIDAR_PCD_PATH = "/home/sabyasachi/Projects/ati/data/data/datasets/Carla/currentDataForCPPR2/static/1/_out"
# MAP_FILE = 'map_CPPR2_static.pcd'
# POSE_FILE = 'pose_CPPR2_static.json'

# %% [markdown]
# ### Set constants and flags

# %%
# FIRST_PCD = 2
# FINAL_PCD = 809
# FIRST_PCD = 2
# FINAL_PCD = 879

VOXEL_SZ = 1
MAKE_2D = True

plt.rcParams['figure.figsize'] = [10, 10]


print("No of grid pts to evaluate per pose: {}".format(X_GRID.shape[0]*Y_GRID.shape[0]*THETA_GRID.shape[0]))
# Out:
# No of grid pts to evaluate per pose: 25625

# %% [markdown]
# ### Functions for pcd io

# %%
def pose2matrix(translation_list, rotation_angle_list):
    trans_vec = np.array(translation_list)
    rot_ang = [np.deg2rad(ang) for ang in rotation_angle_list ]
    rot_mat = transforms3d.euler.euler2mat(rot_ang[0], rot_ang[1], rot_ang[2])
    zoom = np.ones(3)
    transform_mat = transforms3d.affines.compose(trans_vec, rot_mat, zoom)
    return transform_mat

def filter_pcd(old_pcd,
               make_2d = MAKE_2D,
               apply_downsample = True,
               apply_outlier_removal = False,
               apply_crop = True,
               invert_z = INVERT_Z,
               
               downsample_voxel_size = VOXEL_SZ,
               
               downsample_radius = 1,
               downsample_neighbors = 20,
               
               crop_min_arr = np.array([-100,-100,-2]),
               crop_max_arr = np.array([100,100,100]),
               ):
    np.random.seed(0)
    pcd = copy.deepcopy(old_pcd)
    
    if invert_z:
        some_arr = np.asarray(pcd.points)
        some_arr = np.array([(x,y,-z) for x, y, z in some_arr])
        pcd.points = o3d.utility.Vector3dVector(some_arr)
        
    if apply_crop:
        cropped_pcd = o3d.geometry.crop_point_cloud(pcd, crop_min_arr, crop_max_arr)
        pcd = cropped_pcd
    
    if apply_outlier_removal:
        denser_pcd, ind = o3d.geometry.radius_outlier_removal(pcd,
                                                              nb_points = downsample_neighbors,
                                                              radius    = downsample_radius)
        pcd = denser_pcd
    
    if make_2d:
        new_pts = np.concatenate([np.asarray(pcd.points)[:,:-1],np.zeros((len(pcd.points),1))], axis=1)
        pcd.points = o3d.utility.Vector3dVector(new_pts)
    
        
    if apply_downsample:
        voxel_down_pcd = o3d.geometry.voxel_down_sample(pcd, voxel_size = downsample_voxel_size)
        pcd = voxel_down_pcd

    return pcd

# def make_2d(pcd):
#     new_pcd = copy.deepcopy(pcd)
#     new_pts = np.concatenate([np.asarray(pcd.points)[:,:-1],np.zeros((len(pcd.points),1))], axis=1)
#     new_pcd.points = o3d.utility.Vector3dVector(new_pts)
#     return new_pcd

def read_pcd(pcd_id):
    pcd_file = str(pcd_id) + ".ply"
    pcd = o3d.io.read_point_cloud(os.path.join(LIDAR_PCD_PATH, pcd_file))
    return pcd

def draw_pcd(pcd, where='mat_3d'):
    if where is 'opn_nb':
        visualizer = o3d.JVisualizer()
        visualizer.add_geometry(pcd)
        visualizer.show()
    elif where is 'opn_view':
        o3d.visualization.draw_geometries([pcd], width=1280, height=800)
    elif where is 'mat_3d':
        pts = np.asarray(pcd.points)
        plt.scatter(pts[:,0], pts[:,1], pts[:,2])
        plt.show()
    elif where is 'mat_2d':
        pts = np.asarray(pcd.points)
        plt.scatter(pts[:,0], pts[:,1])
        plt.show()
        
def draw_registration_result(src_pcd, dst_pcd, x_pt, y_pt, theta):    
    src_pcd_tmp = copy.deepcopy(src_pcd)
    dst_pcd_tmp = copy.deepcopy(dst_pcd)
    
    src_pcd_tmp.paint_uniform_color([1, 0, 0])  # red source
    dst_pcd_tmp.paint_uniform_color([0, 0, 1])  # blue target
    
    transform_mat = pose2matrix([x_pt, y_pt, 0], [0,0,theta])
    dst_pcd_tmp.transform(transform_mat)
    
    visualizer = o3d.JVisualizer()
    visualizer.add_geometry(src_pcd_tmp)
    visualizer.add_geometry(dst_pcd_tmp)
    visualizer.show()

# %% [markdown]
# ### Functions for pose estimation and scoring

# %%
def score_pts(src_pcd, dst_pcd, trans_arr=np.zeros(3), rot_ang=np.zeros(3)):
    NEIGHB_RADIUS = VOXEL_SZ
    
    src_tmp_pcd = copy.deepcopy(src_pcd)
    dst_tmp_pcd = copy.deepcopy(dst_pcd)
    
    transform_mat = pose2matrix(trans_arr, rot_ang)
    # Note: we apply transformation on target pcd to directly get pose (without sign change)
    dst_tmp_pcd.transform(transform_mat)
    
    score = o3d.registration.evaluate_registration(src_tmp_pcd, dst_tmp_pcd, NEIGHB_RADIUS)
    
    fit = score.fitness
    rmse = score.inlier_rmse
    n_pairs = np.asarray(score.correspondence_set).shape[0]
    return rmse, fit, n_pairs

def parallel_thread(parallel_arg):
    grid_pts, previous_pose, previous_velocity = parallel_arg[0], parallel_arg[1], parallel_arg[2]
    x_pt, y_pt, theta_pt = grid_pts[0], grid_pts[1], grid_pts[2]
    x_src, y_src, theta_src = previous_pose[0], previous_pose[1], previous_pose[2]
    x_vel, y_vel, theta_vel = previous_velocity[0], previous_velocity[1], previous_velocity[2]
    
    x = x_src + x_vel + x_pt
    y = y_src + y_vel + y_pt
    t = theta_src + theta_vel + theta_pt
    rmse, fit, n_pairs = score_pts(map_pcd, new_pcd,
                                   trans_arr = [x, y, 0],
                                   rot_ang   = [0, 0, t])
    result = {'x' : x,
              'y' : y,
              'theta' : t,
              
              'x_vel' : x_vel + x_pt,
              'y_vel' : y_vel + y_pt,
              'theta_vel' : theta_vel + theta_pt,
              
              'rmse' : rmse,
              'fit' : fit,
              'n_pairs' : n_pairs}
    return result

# %% [markdown]
# ### Implementation

# %% [markdown]
# #### Create initial map

# %%
map_pcd = read_pcd(FIRST_PCD)
map_pcd = filter_pcd(map_pcd)
print(map_pcd)
# Out:
# geometry::PointCloud with 218 points.

# %% [markdown]
# #### Initialize pose arrays

# %%
pose_list = []
global_origin_pt = {'x' : 0,
                    'y' : 0,
                    'theta' : 0,
                    
                    'x_vel' : 0,
                    'y_vel' : 0,
                    'theta_vel' : 0,
                    
                    'rmse' : 0,
                    'fit' : 1,
                    'n_pairs' : np.asarray(map_pcd.points).shape[0]}
pose_list.append(global_origin_pt)

# %% [markdown]
# #### Iterate over all subsequent pcds for local pose estimation and building the map

# %%
for pcd_idx in tqdm_notebook(range(FIRST_PCD+1, FINAL_PCD+1)):
    # Read next pcd and filter it
    new_pcd = read_pcd(pcd_idx)
    new_pcd = filter_pcd(new_pcd)

    # Extract last pose
    x_src, y_src, theta_src = pose_list[-1]['x'], pose_list[-1]['y'], pose_list[-1]['theta']
    x_vel, y_vel, theta_vel = pose_list[-1]['x_vel'], pose_list[-1]['y_vel'], pose_list[-1]['theta_vel']
    
    # Extract all grid pts
    parallel_args = [([x_pt, y_pt, theta], [x_src, y_src, theta_src], [x_vel, y_vel, theta_vel])\
                     for x_pt in X_GRID for y_pt in Y_GRID for theta in THETA_GRID]
    
    # Score on all grid pts
    process_pool = Pool(cpu_count()-1)
    score_list = [each for each in process_pool.imap_unordered(parallel_thread, parallel_args)]
    process_pool.terminate()
    
    # Extract pose with best matching score
    df_score = pd.DataFrame(score_list)
    new_pose_pt = df_score.iloc[df_score.fit.argmax()].to_dict()
    pose_list.append(new_pose_pt)

    # Transform this pcd based on the best pose
    new_tmp_pcd = copy.deepcopy(new_pcd)
    transform_mat = pose2matrix([new_pose_pt['x'], new_pose_pt['y'], 0],
                                 [0, 0, new_pose_pt['theta']])
    new_tmp_pcd.transform(transform_mat)

    # Add the current transformed pcd to the map
    map_pcd.points = o3d.utility.Vector3dVector(np.concatenate((np.asarray(map_pcd.points),
                                                                 np.asarray(new_tmp_pcd.points)), axis=0))

    map_pcd = filter_pcd(map_pcd, apply_outlier_removal=False)
    
    # Checkpoint the new map and pose array to files
    o3d.io.write_point_cloud(MAP_FILE, map_pcd)
    pd.DataFrame(pose_list).to_json(POSE_FILE, orient='records', lines=True)
    
    gc.collect()
    
    print(map_pcd)
# Out:
# HBox(children=(IntProgress(value=0, max=1198), HTML(value='')))
# geometry::PointCloud with 217 points.
# geometry::PointCloud with 262 points.
# geometry::PointCloud with 297 points.
# geometry::PointCloud with 404 points.
# geometry::PointCloud with 445 points.
# geometry::PointCloud with 468 points.
# geometry::PointCloud with 459 points.
# geometry::PointCloud with 466 points.
# geometry::PointCloud with 476 points.
# geometry::PointCloud with 489 points.
# geometry::PointCloud with 475 points.
# geometry::PointCloud with 462 points.
# geometry::PointCloud with 475 points.
# geometry::PointCloud with 477 points.
# geometry::PointCloud with 478 points.
# geometry::PointCloud with 470 points.
# geometry::PointCloud with 470 points.
# geometry::PointCloud with 454 points.
# geometry::PointCloud with 461 points.
# geometry::PointCloud with 464 points.
# geometry::PointCloud with 457 points.
# geometry::PointCloud with 465 points.
# geometry::PointCloud with 458 points.
# geometry::PointCloud with 462 points.
# geometry::PointCloud with 464 points.
# geometry::PointCloud with 459 points.
# geometry::PointCloud with 459 points.
# geometry::PointCloud with 461 points.
# geometry::PointCloud with 460 points.
# geometry::PointCloud with 466 points.
# geometry::PointCloud with 476 points.
# geometry::PointCloud with 480 points.
# geometry::PointCloud with 479 points.
# geometry::PointCloud with 488 points.
# geometry::PointCloud with 472 points.
# geometry::PointCloud with 463 points.
# geometry::PointCloud with 469 points.
# geometry::PointCloud with 492 points.
# geometry::PointCloud with 521 points.
# geometry::PointCloud with 557 points.
# geometry::PointCloud with 485 points.
# geometry::PointCloud with 536 points.
# geometry::PointCloud with 567 points.
# geometry::PointCloud with 548 points.
# geometry::PointCloud with 548 points.
# geometry::PointCloud with 590 points.
# geometry::PointCloud with 595 points.
# geometry::PointCloud with 621 points.
# geometry::PointCloud with 572 points.
# geometry::PointCloud with 566 points.
# geometry::PointCloud with 605 points.
# geometry::PointCloud with 621 points.
# geometry::PointCloud with 661 points.
# geometry::PointCloud with 679 points.
# geometry::PointCloud with 687 points.
# geometry::PointCloud with 704 points.
# geometry::PointCloud with 692 points.
# geometry::PointCloud with 673 points.
# geometry::PointCloud with 687 points.
# geometry::PointCloud with 695 points.
# geometry::PointCloud with 608 points.
# geometry::PointCloud with 553 points.
# geometry::PointCloud with 635 points.
# geometry::PointCloud with 587 points.
# geometry::PointCloud with 629 points.
# geometry::PointCloud with 587 points.
# geometry::PointCloud with 604 points.
# geometry::PointCloud with 600 points.
# geometry::PointCloud with 601 points.
# geometry::PointCloud with 628 points.
# geometry::PointCloud with 621 points.
# geometry::PointCloud with 566 points.
# geometry::PointCloud with 598 points.
# geometry::PointCloud with 591 points.
# geometry::PointCloud with 608 points.
# geometry::PointCloud with 624 points.
# geometry::PointCloud with 618 points.
# geometry::PointCloud with 625 points.
# geometry::PointCloud with 669 points.
# geometry::PointCloud with 629 points.
# geometry::PointCloud with 643 points.
# geometry::PointCloud with 655 points.
# geometry::PointCloud with 640 points.
# geometry::PointCloud with 652 points.
# geometry::PointCloud with 666 points.
# geometry::PointCloud with 693 points.
# geometry::PointCloud with 673 points.
# geometry::PointCloud with 677 points.
# geometry::PointCloud with 684 points.
# geometry::PointCloud with 715 points.
# geometry::PointCloud with 725 points.
# geometry::PointCloud with 727 points.
# geometry::PointCloud with 738 points.
# geometry::PointCloud with 731 points.
# geometry::PointCloud with 736 points.
# geometry::PointCloud with 737 points.
# geometry::PointCloud with 751 points.
# geometry::PointCloud with 773 points.
# geometry::PointCloud with 773 points.
# geometry::PointCloud with 777 points.
# geometry::PointCloud with 790 points.
# geometry::PointCloud with 794 points.
# geometry::PointCloud with 794 points.
# geometry::PointCloud with 798 points.
# geometry::PointCloud with 799 points.
# geometry::PointCloud with 802 points.
# geometry::PointCloud with 802 points.
# geometry::PointCloud with 722 points.
# geometry::PointCloud with 678 points.
# geometry::PointCloud with 693 points.
# geometry::PointCloud with 697 points.
# geometry::PointCloud with 707 points.
# geometry::PointCloud with 682 points.
# geometry::PointCloud with 702 points.
# geometry::PointCloud with 700 points.
# geometry::PointCloud with 674 points.
# geometry::PointCloud with 654 points.
# geometry::PointCloud with 662 points.
# geometry::PointCloud with 671 points.
# geometry::PointCloud with 681 points.
# geometry::PointCloud with 678 points.
# geometry::PointCloud with 695 points.
# geometry::PointCloud with 705 points.
# geometry::PointCloud with 721 points.
# geometry::PointCloud with 732 points.
# geometry::PointCloud with 650 points.
# geometry::PointCloud with 676 points.
# geometry::PointCloud with 693 points.
# geometry::PointCloud with 718 points.
# geometry::PointCloud with 723 points.
# geometry::PointCloud with 732 points.
# geometry::PointCloud with 759 points.
# geometry::PointCloud with 688 points.
# geometry::PointCloud with 676 points.
# geometry::PointCloud with 694 points.
# geometry::PointCloud with 679 points.
# geometry::PointCloud with 702 points.
# geometry::PointCloud with 714 points.
# geometry::PointCloud with 742 points.
# geometry::PointCloud with 753 points.
# geometry::PointCloud with 759 points.
# geometry::PointCloud with 760 points.
# geometry::PointCloud with 769 points.
# geometry::PointCloud with 775 points.
# geometry::PointCloud with 781 points.
# geometry::PointCloud with 783 points.
# geometry::PointCloud with 745 points.
# geometry::PointCloud with 751 points.
# geometry::PointCloud with 720 points.
# geometry::PointCloud with 726 points.
# geometry::PointCloud with 729 points.
# geometry::PointCloud with 737 points.
# geometry::PointCloud with 737 points.
# geometry::PointCloud with 743 points.
# geometry::PointCloud with 752 points.
# geometry::PointCloud with 760 points.
# geometry::PointCloud with 699 points.
# geometry::PointCloud with 696 points.
# geometry::PointCloud with 707 points.
# geometry::PointCloud with 716 points.
# geometry::PointCloud with 739 points.
# geometry::PointCloud with 750 points.
# geometry::PointCloud with 757 points.
# geometry::PointCloud with 763 points.
# geometry::PointCloud with 717 points.
# geometry::PointCloud with 731 points.
# geometry::PointCloud with 750 points.
# geometry::PointCloud with 781 points.
# geometry::PointCloud with 790 points.
# geometry::PointCloud with 794 points.
# geometry::PointCloud with 804 points.
# geometry::PointCloud with 826 points.
# geometry::PointCloud with 828 points.
# geometry::PointCloud with 832 points.
# geometry::PointCloud with 833 points.
# geometry::PointCloud with 837 points.
# geometry::PointCloud with 830 points.
# geometry::PointCloud with 795 points.
# geometry::PointCloud with 805 points.
# geometry::PointCloud with 815 points.
# geometry::PointCloud with 815 points.
# geometry::PointCloud with 816 points.
# geometry::PointCloud with 820 points.
# geometry::PointCloud with 774 points.
# geometry::PointCloud with 773 points.
# geometry::PointCloud with 778 points.
# geometry::PointCloud with 791 points.
# geometry::PointCloud with 750 points.
# geometry::PointCloud with 748 points.
# geometry::PointCloud with 749 points.
# geometry::PointCloud with 790 points.
# geometry::PointCloud with 783 points.
# geometry::PointCloud with 785 points.
# geometry::PointCloud with 739 points.
# geometry::PointCloud with 738 points.
# geometry::PointCloud with 749 points.
# geometry::PointCloud with 742 points.
# geometry::PointCloud with 754 points.
# geometry::PointCloud with 745 points.
# geometry::PointCloud with 745 points.
# geometry::PointCloud with 743 points.
# geometry::PointCloud with 726 points.
# geometry::PointCloud with 732 points.
# geometry::PointCloud with 739 points.
# geometry::PointCloud with 747 points.
# geometry::PointCloud with 773 points.
# geometry::PointCloud with 745 points.
# geometry::PointCloud with 749 points.
# geometry::PointCloud with 752 points.
# geometry::PointCloud with 771 points.
# geometry::PointCloud with 768 points.
# geometry::PointCloud with 771 points.
# geometry::PointCloud with 774 points.
# geometry::PointCloud with 780 points.
# geometry::PointCloud with 785 points.
# geometry::PointCloud with 796 points.
# geometry::PointCloud with 779 points.
# geometry::PointCloud with 793 points.
# geometry::PointCloud with 797 points.
# geometry::PointCloud with 798 points.
# geometry::PointCloud with 798 points.
# geometry::PointCloud with 743 points.
# geometry::PointCloud with 766 points.
# geometry::PointCloud with 772 points.
# geometry::PointCloud with 769 points.
# geometry::PointCloud with 749 points.
# geometry::PointCloud with 769 points.
# geometry::PointCloud with 776 points.
# geometry::PointCloud with 788 points.
# geometry::PointCloud with 766 points.
# geometry::PointCloud with 770 points.
# geometry::PointCloud with 776 points.
# geometry::PointCloud with 778 points.
# geometry::PointCloud with 780 points.
# geometry::PointCloud with 788 points.
# geometry::PointCloud with 804 points.
# geometry::PointCloud with 809 points.
# geometry::PointCloud with 821 points.
# geometry::PointCloud with 842 points.
# geometry::PointCloud with 845 points.
# geometry::PointCloud with 847 points.
# geometry::PointCloud with 854 points.
# geometry::PointCloud with 858 points.
# geometry::PointCloud with 861 points.
# geometry::PointCloud with 863 points.
# geometry::PointCloud with 870 points.
# geometry::PointCloud with 873 points.
# geometry::PointCloud with 876 points.
# geometry::PointCloud with 879 points.
# geometry::PointCloud with 881 points.
# geometry::PointCloud with 886 points.
# geometry::PointCloud with 891 points.
# geometry::PointCloud with 893 points.
# geometry::PointCloud with 897 points.
# geometry::PointCloud with 902 points.
# geometry::PointCloud with 907 points.
# geometry::PointCloud with 909 points.
# geometry::PointCloud with 921 points.
# geometry::PointCloud with 931 points.
# geometry::PointCloud with 936 points.
# geometry::PointCloud with 940 points.
# geometry::PointCloud with 944 points.
# geometry::PointCloud with 953 points.
# geometry::PointCloud with 953 points.
# geometry::PointCloud with 955 points.
# geometry::PointCloud with 957 points.
# geometry::PointCloud with 961 points.
# geometry::PointCloud with 961 points.
# geometry::PointCloud with 963 points.
# geometry::PointCloud with 967 points.
# geometry::PointCloud with 973 points.
# geometry::PointCloud with 974 points.
# geometry::PointCloud with 976 points.
# geometry::PointCloud with 978 points.
# geometry::PointCloud with 978 points.
# geometry::PointCloud with 978 points.
# geometry::PointCloud with 979 points.
# geometry::PointCloud with 980 points.
# geometry::PointCloud with 981 points.
# geometry::PointCloud with 983 points.
# geometry::PointCloud with 985 points.
# geometry::PointCloud with 987 points.
# geometry::PointCloud with 993 points.
# geometry::PointCloud with 995 points.
# geometry::PointCloud with 997 points.
# geometry::PointCloud with 998 points.
# geometry::PointCloud with 1016 points.
# geometry::PointCloud with 1017 points.
# geometry::PointCloud with 1017 points.
# geometry::PointCloud with 1019 points.
# geometry::PointCloud with 1025 points.
# geometry::PointCloud with 1023 points.
# geometry::PointCloud with 1023 points.
# geometry::PointCloud with 1024 points.
# geometry::PointCloud with 1026 points.
# geometry::PointCloud with 1026 points.
# geometry::PointCloud with 1027 points.
# geometry::PointCloud with 1026 points.
# geometry::PointCloud with 1026 points.
# geometry::PointCloud with 1026 points.
# geometry::PointCloud with 1028 points.
# geometry::PointCloud with 1028 points.
# geometry::PointCloud with 1031 points.
# geometry::PointCloud with 1032 points.
# geometry::PointCloud with 1034 points.
# geometry::PointCloud with 1037 points.
# geometry::PointCloud with 1037 points.
# geometry::PointCloud with 1038 points.
# geometry::PointCloud with 1038 points.
# geometry::PointCloud with 1038 points.
# geometry::PointCloud with 1038 points.
# geometry::PointCloud with 1041 points.
# geometry::PointCloud with 1042 points.
# geometry::PointCloud with 1044 points.
# geometry::PointCloud with 1046 points.
# geometry::PointCloud with 1043 points.
# geometry::PointCloud with 1051 points.
# geometry::PointCloud with 1056 points.
# geometry::PointCloud with 1064 points.
# geometry::PointCloud with 1073 points.
# geometry::PointCloud with 1073 points.
# geometry::PointCloud with 1074 points.
# geometry::PointCloud with 1083 points.
# geometry::PointCloud with 1087 points.
# geometry::PointCloud with 1090 points.
# geometry::PointCloud with 1096 points.
# geometry::PointCloud with 1100 points.
# geometry::PointCloud with 1108 points.
# geometry::PointCloud with 1099 points.
# geometry::PointCloud with 1100 points.
# geometry::PointCloud with 1109 points.
# geometry::PointCloud with 1115 points.
# geometry::PointCloud with 1130 points.
# geometry::PointCloud with 1136 points.
# geometry::PointCloud with 1145 points.
# geometry::PointCloud with 1149 points.
# geometry::PointCloud with 1159 points.
# geometry::PointCloud with 1163 points.
# geometry::PointCloud with 1170 points.
# geometry::PointCloud with 1174 points.
# geometry::PointCloud with 1181 points.
# geometry::PointCloud with 1186 points.
# geometry::PointCloud with 1191 points.
# geometry::PointCloud with 1197 points.
# geometry::PointCloud with 1206 points.
# geometry::PointCloud with 1213 points.
# geometry::PointCloud with 1217 points.
# geometry::PointCloud with 1216 points.
# geometry::PointCloud with 1222 points.
# geometry::PointCloud with 1225 points.
# geometry::PointCloud with 1226 points.
# geometry::PointCloud with 1227 points.
# geometry::PointCloud with 1234 points.
# geometry::PointCloud with 1243 points.
# geometry::PointCloud with 1247 points.
# geometry::PointCloud with 1248 points.
# geometry::PointCloud with 1249 points.
# geometry::PointCloud with 1251 points.
# geometry::PointCloud with 1251 points.
# geometry::PointCloud with 1255 points.
# geometry::PointCloud with 1257 points.
# geometry::PointCloud with 1260 points.
# geometry::PointCloud with 1261 points.
# geometry::PointCloud with 1266 points.
# geometry::PointCloud with 1274 points.
# geometry::PointCloud with 1277 points.
# geometry::PointCloud with 1279 points.
# geometry::PointCloud with 1282 points.
# geometry::PointCloud with 1108 points.
# geometry::PointCloud with 1112 points.
# geometry::PointCloud with 1113 points.
# geometry::PointCloud with 1117 points.
# geometry::PointCloud with 1120 points.
# geometry::PointCloud with 1130 points.
# geometry::PointCloud with 1132 points.
# geometry::PointCloud with 1136 points.
# geometry::PointCloud with 1141 points.
# geometry::PointCloud with 1142 points.
# geometry::PointCloud with 1145 points.
# geometry::PointCloud with 1147 points.
# geometry::PointCloud with 1148 points.
# geometry::PointCloud with 1148 points.
# geometry::PointCloud with 1154 points.
# geometry::PointCloud with 1116 points.
# geometry::PointCloud with 1123 points.
# geometry::PointCloud with 1126 points.
# geometry::PointCloud with 1112 points.
# geometry::PointCloud with 1113 points.
# geometry::PointCloud with 1103 points.
# geometry::PointCloud with 1101 points.
# geometry::PointCloud with 1024 points.
# geometry::PointCloud with 956 points.
# geometry::PointCloud with 994 points.
# geometry::PointCloud with 991 points.
# geometry::PointCloud with 979 points.
# geometry::PointCloud with 948 points.
# geometry::PointCloud with 930 points.
# geometry::PointCloud with 951 points.
# geometry::PointCloud with 924 points.
# geometry::PointCloud with 959 points.
# geometry::PointCloud with 978 points.
# geometry::PointCloud with 928 points.
# geometry::PointCloud with 951 points.
# geometry::PointCloud with 964 points.
# geometry::PointCloud with 961 points.
# geometry::PointCloud with 968 points.
# geometry::PointCloud with 976 points.
# geometry::PointCloud with 993 points.
# geometry::PointCloud with 1004 points.
# geometry::PointCloud with 1011 points.
# geometry::PointCloud with 983 points.
# geometry::PointCloud with 992 points.
# geometry::PointCloud with 995 points.
# geometry::PointCloud with 987 points.
# geometry::PointCloud with 1008 points.
# geometry::PointCloud with 1015 points.
# geometry::PointCloud with 1025 points.
# geometry::PointCloud with 1044 points.
# geometry::PointCloud with 1003 points.
# geometry::PointCloud with 984 points.
# geometry::PointCloud with 996 points.
# geometry::PointCloud with 1012 points.
# geometry::PointCloud with 1029 points.
# geometry::PointCloud with 1025 points.
# geometry::PointCloud with 1028 points.
# geometry::PointCloud with 1023 points.
# geometry::PointCloud with 1020 points.
# geometry::PointCloud with 1001 points.
# geometry::PointCloud with 1009 points.
# geometry::PointCloud with 1016 points.
# geometry::PointCloud with 969 points.
# geometry::PointCloud with 981 points.
# geometry::PointCloud with 994 points.
# geometry::PointCloud with 1014 points.
# geometry::PointCloud with 1032 points.
# geometry::PointCloud with 1031 points.
# geometry::PointCloud with 1025 points.
# geometry::PointCloud with 990 points.
# geometry::PointCloud with 1016 points.
# geometry::PointCloud with 1022 points.
# geometry::PointCloud with 1034 points.
# geometry::PointCloud with 1038 points.
# geometry::PointCloud with 1042 points.
# geometry::PointCloud with 1055 points.
# geometry::PointCloud with 1063 points.
# geometry::PointCloud with 1077 points.
# geometry::PointCloud with 1085 points.
# geometry::PointCloud with 1063 points.
# geometry::PointCloud with 1066 points.
# geometry::PointCloud with 1071 points.
# geometry::PointCloud with 1014 points.
# geometry::PointCloud with 1019 points.
# geometry::PointCloud with 1023 points.
# geometry::PointCloud with 1042 points.
# geometry::PointCloud with 1041 points.
# geometry::PointCloud with 1048 points.
# geometry::PointCloud with 1049 points.
# geometry::PointCloud with 1061 points.
# geometry::PointCloud with 1064 points.
# geometry::PointCloud with 1061 points.
# geometry::PointCloud with 1072 points.
# geometry::PointCloud with 1089 points.
# geometry::PointCloud with 1053 points.
# geometry::PointCloud with 1056 points.
# geometry::PointCloud with 1078 points.
# geometry::PointCloud with 1101 points.
# geometry::PointCloud with 1101 points.
# geometry::PointCloud with 1085 points.
# geometry::PointCloud with 1107 points.
# geometry::PointCloud with 1061 points.
# geometry::PointCloud with 1077 points.
# geometry::PointCloud with 1087 points.
# geometry::PointCloud with 1079 points.
# geometry::PointCloud with 1078 points.
# geometry::PointCloud with 1083 points.
# geometry::PointCloud with 1089 points.
# geometry::PointCloud with 1098 points.
# geometry::PointCloud with 1106 points.
# geometry::PointCloud with 1064 points.
# geometry::PointCloud with 1058 points.
# geometry::PointCloud with 1087 points.
# geometry::PointCloud with 1116 points.
# geometry::PointCloud with 1083 points.
# geometry::PointCloud with 1092 points.
# geometry::PointCloud with 1108 points.
# geometry::PointCloud with 1090 points.
# geometry::PointCloud with 1098 points.
# geometry::PointCloud with 1092 points.
# geometry::PointCloud with 1109 points.
# geometry::PointCloud with 1125 points.
# geometry::PointCloud with 1109 points.
# geometry::PointCloud with 1071 points.
# geometry::PointCloud with 1091 points.
# geometry::PointCloud with 1119 points.
# geometry::PointCloud with 1078 points.
# geometry::PointCloud with 1090 points.
# geometry::PointCloud with 1092 points.
# geometry::PointCloud with 1088 points.
# geometry::PointCloud with 1085 points.
# geometry::PointCloud with 1098 points.
# geometry::PointCloud with 1111 points.
# geometry::PointCloud with 1127 points.
# geometry::PointCloud with 1157 points.
# geometry::PointCloud with 1162 points.
# geometry::PointCloud with 1171 points.
# geometry::PointCloud with 1177 points.
# geometry::PointCloud with 1169 points.
# geometry::PointCloud with 1177 points.
# geometry::PointCloud with 1167 points.
# geometry::PointCloud with 1164 points.
# geometry::PointCloud with 1186 points.
# geometry::PointCloud with 1145 points.
# geometry::PointCloud with 1163 points.
# geometry::PointCloud with 1188 points.
# geometry::PointCloud with 1195 points.
# geometry::PointCloud with 1206 points.
# geometry::PointCloud with 1211 points.
# geometry::PointCloud with 1251 points.
# geometry::PointCloud with 1269 points.
# geometry::PointCloud with 1272 points.
# geometry::PointCloud with 1272 points.
# geometry::PointCloud with 1191 points.
# geometry::PointCloud with 1211 points.
# geometry::PointCloud with 1226 points.
# geometry::PointCloud with 1255 points.
# geometry::PointCloud with 1275 points.
# geometry::PointCloud with 1282 points.
# geometry::PointCloud with 1297 points.
# geometry::PointCloud with 1263 points.
# geometry::PointCloud with 1266 points.
# geometry::PointCloud with 1283 points.
# geometry::PointCloud with 1308 points.
# geometry::PointCloud with 1308 points.
# geometry::PointCloud with 1314 points.
# geometry::PointCloud with 1310 points.
# geometry::PointCloud with 1325 points.
# geometry::PointCloud with 1236 points.
# geometry::PointCloud with 1250 points.
# geometry::PointCloud with 1282 points.
# geometry::PointCloud with 1303 points.
# geometry::PointCloud with 1293 points.
# geometry::PointCloud with 1310 points.
# geometry::PointCloud with 1330 points.
# geometry::PointCloud with 1342 points.
# geometry::PointCloud with 1349 points.
# geometry::PointCloud with 1248 points.
# geometry::PointCloud with 1282 points.
# geometry::PointCloud with 1289 points.
# geometry::PointCloud with 1303 points.
# geometry::PointCloud with 1303 points.
# geometry::PointCloud with 1313 points.
# geometry::PointCloud with 1346 points.
# geometry::PointCloud with 1278 points.
# geometry::PointCloud with 1284 points.
# geometry::PointCloud with 1296 points.
# geometry::PointCloud with 1333 points.
# geometry::PointCloud with 1337 points.
# geometry::PointCloud with 1258 points.
# geometry::PointCloud with 1296 points.
# geometry::PointCloud with 1316 points.
# geometry::PointCloud with 1326 points.
# geometry::PointCloud with 1331 points.
# geometry::PointCloud with 1345 points.
# geometry::PointCloud with 1360 points.
# geometry::PointCloud with 1367 points.
# geometry::PointCloud with 1286 points.
# geometry::PointCloud with 1291 points.
# geometry::PointCloud with 1339 points.
# geometry::PointCloud with 1355 points.
# geometry::PointCloud with 1361 points.
# geometry::PointCloud with 1366 points.
# geometry::PointCloud with 1372 points.
# geometry::PointCloud with 1379 points.
# geometry::PointCloud with 1382 points.
# geometry::PointCloud with 1363 points.
# geometry::PointCloud with 1373 points.
# geometry::PointCloud with 1365 points.
# geometry::PointCloud with 1369 points.
# geometry::PointCloud with 1371 points.
# geometry::PointCloud with 1386 points.
# geometry::PointCloud with 1402 points.
# geometry::PointCloud with 1408 points.
# geometry::PointCloud with 1402 points.
# geometry::PointCloud with 1406 points.
# geometry::PointCloud with 1414 points.
# geometry::PointCloud with 1425 points.
# geometry::PointCloud with 1427 points.
# geometry::PointCloud with 1430 points.
# geometry::PointCloud with 1433 points.
# geometry::PointCloud with 1437 points.
# geometry::PointCloud with 1430 points.
# geometry::PointCloud with 1435 points.
# geometry::PointCloud with 1439 points.
# geometry::PointCloud with 1449 points.
# geometry::PointCloud with 1454 points.
# geometry::PointCloud with 1459 points.
# geometry::PointCloud with 1465 points.
# geometry::PointCloud with 1468 points.
# geometry::PointCloud with 1437 points.
# geometry::PointCloud with 1441 points.
# geometry::PointCloud with 1469 points.
# geometry::PointCloud with 1476 points.
# geometry::PointCloud with 1480 points.
# geometry::PointCloud with 1481 points.
# geometry::PointCloud with 1492 points.
# geometry::PointCloud with 1487 points.
# geometry::PointCloud with 1482 points.
# geometry::PointCloud with 1491 points.
# geometry::PointCloud with 1498 points.
# geometry::PointCloud with 1509 points.
# geometry::PointCloud with 1512 points.
# Process ForkPoolWorker-14057:
# Process ForkPoolWorker-14067:
# Process ForkPoolWorker-14066:
# Process ForkPoolWorker-14076:
# Process ForkPoolWorker-14075:
# Process ForkPoolWorker-14059:
# Process ForkPoolWorker-14065:
# Traceback (most recent call last):
# Process ForkPoolWorker-14056:
# Process ForkPoolWorker-14063:
# Process ForkPoolWorker-14058:
# Process ForkPoolWorker-14074:
# Process ForkPoolWorker-14054:
# Process ForkPoolWorker-14060:
# Process ForkPoolWorker-14068:
# Process ForkPoolWorker-14069:
# Process ForkPoolWorker-14061:
# Process ForkPoolWorker-14055:
# Process ForkPoolWorker-14072:
# Process ForkPoolWorker-14070:
# Process ForkPoolWorker-14073:
# Process ForkPoolWorker-14062:
# Process ForkPoolWorker-14064:
# Traceback (most recent call last):
# Process ForkPoolWorker-14071:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/sabyasachi/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     732             try:
# --> 733                 item = self._items.popleft()
#     734             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4b1d746d375a> in <module>
#      14     # Score on all grid pts
#      15     process_pool = Pool(cpu_count()-1)
# ---> 16     score_list = [each for each in process_pool.imap_unordered(parallel_thread, parallel_args)]
#      17     process_pool.terminate()
#      18
#
# <ipython-input-8-4b1d746d375a> in <listcomp>(.0)
#      14     # Score on all grid pts
#      15     process_pool = Pool(cpu_count()-1)
# ---> 16     score_list = [each for each in process_pool.imap_unordered(parallel_thread, parallel_args)]
#      17     process_pool.terminate()
#      18
#
# ~/anaconda3/envs/deepmapping/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     735                 if self._index == self._length:
#     736                     raise StopIteration from None
# --> 737                 self._cond.wait(timeout)
#     738                 try:
#     739                     item = self._items.popleft()
#
# ~/anaconda3/envs/deepmapping/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Verifying completing of SLAM iterations

# %%
pcd_idx

# %%
map_pcd

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Look at the Map

# %%
map_pcd

# %%
draw_pcd(map_pcd, where='mat_3d')
draw_pcd(map_pcd, where='mat_2d')

# %%
draw_pcd(map_pcd, where='opn_nb')

# %% [markdown]
# #### Look at the Poses

# %%
df_pose = pd.DataFrame(pose_list)

# %%
plt.scatter(df_pose['x'], df_pose['y'])

# %% [markdown]
# #### Did we hit the velocity boundary ?

# %%
df_pose['x_abs'] = [0] + [df_pose.iloc[idx]['x_vel']- df_pose.iloc[idx-1]['x_vel'] for idx in range(df_pose.shape[0]) if idx != 0]
df_pose['y_abs'] = [0] + [df_pose.iloc[idx]['y_vel']- df_pose.iloc[idx-1]['y_vel'] for idx in range(df_pose.shape[0]) if idx != 0]
df_pose['theta_abs'] = [0] + [df_pose.iloc[idx]['theta_vel']- df_pose.iloc[idx-1]['theta_vel'] for idx in range(df_pose.shape[0]) if idx != 0]

# %% [raw]
# print(X_GRID[0], X_GRID[-1])
# print(df_pose['x_abs'].min(), df_pose['x_abs'].max())
# print("")
# print(Y_GRID[0], Y_GRID[-1])
# print(df_pose['y_abs'].min(), df_pose['y_abs'].max())
# print("")
# print(THETA_GRID[0], THETA_GRID[-1])
# print(df_pose['theta_abs'].min(), df_pose['theta_abs'].max())

# %%
if df_pose['x_abs'].min() <= X_GRID[0]:
    print("Velocity boundary hit in -X direction")
    print("Expected: {} | Real : {}".format(X_GRID[0], df_pose['x_abs'].min()))

if df_pose['y_abs'].min() <= Y_GRID[0]:
    print("Velocity boundary hit in -Y direction")
    print("Expected: {} | Real : {}".format(Y_GRID[0], df_pose['y_abs'].min()))
    
if df_pose['theta_abs'].min() <= THETA_GRID[0]:
    print("Velocity boundary hit in -THETA direction")
    print("Expected: {} | Real : {}".format(THETA_GRID[0], df_pose['theta_abs'].min()))
    
if df_pose['x_abs'].max() >= X_GRID[-1]:
    print("Velocity boundary hit in +X direction")
    print("Expected: {} | Real : {}".format(X_GRID[-1], df_pose['x_abs'].max()))
    
if df_pose['y_abs'].max() >= Y_GRID[-1]:
    print("Velocity boundary hit in +Y direction")
    print("Expected: {} | Real : {}".format(Y_GRID[-1], df_pose['y_abs'].max()))

if df_pose['theta_abs'].max() >= THETA_GRID[-1]:
    print("Velocity boundary hit in +THETA direction")
    print("Expected: {} | Real : {}".format(THETA_GRID[-1], df_pose['theta_abs'].max()))
    
print("All clear?")
